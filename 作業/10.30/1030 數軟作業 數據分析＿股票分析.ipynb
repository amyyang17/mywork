# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("http://www.twse.com.tw/exchangeReport/STOCK_DAY_ALL?response=open_data")
dfg=pd.read_csv("http://www.tpex.org.tw/web/stock/aftertrading/DAILY_CLOSE_quotes/stk_quote_result.php?l=zh-tw&o=data")

# %%
df.head()
# Out:
#    證券代號     證券名稱       成交股數         成交金額    開盤價    最高價    最低價    收盤價   漲跌價差  \
# 0  0050   元大台灣50  3,050,118  282,827,556  93.20  93.20  92.35  92.85  -0.50
# 1  0051  元大中型100     17,540      622,430  35.60  35.63  35.30  35.30  -0.30
# 2  0052     富邦科技    124,637    8,368,989  67.75  67.75  66.95  67.10  -0.75
# 3  0053     元大電子     23,000      954,720  41.74  41.74  41.40  41.40  -0.19
# 4  0054   元大台商50      9,005      222,664  24.79  24.79  24.57  24.72  -0.17
#
#     成交筆數
# 0  1,940
# 1     24
# 2     61
# 3     21
# 4      9

# %%
df.columns
# Out:
# Index(['證券代號', '證券名稱', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差',
#        '成交筆數'],
#       dtype='object')

# %%
df.sort_values(by='漲跌價差',ascending=False).head()
# Out:
#         證券代號       證券名稱    成交股數     成交金額     開盤價     最高價     最低價     收盤價  \
# 86    00707R  元大S&P日圓反1   1,000   19,920   19.92   19.92   19.92   19.92
# 713     3130        一零四   1,097  185,393  169.00  169.00  169.00  169.00
# 135   020002     元富新中國N   1,000   14,480   14.48   14.48   14.48   14.48
# 136   020004   兆豐電菁英30N   1,000   22,360   22.36   22.36   22.36   22.36
# 1086    9929         秋雨  13,435  178,235   13.40   13.55   13.00   13.55
#
#        漲跌價差 成交筆數
# 86    X0.00    1
# 713   X0.00    3
# 135   X0.00    1
# 136   X0.00    1
# 1086  X0.00   10

# %%
df[df.證券代號=='3130']
# Out:
#      證券代號 證券名稱   成交股數     成交金額     開盤價     最高價     最低價     收盤價   漲跌價差 成交筆數
# 713  3130  一零四  1,097  185,393  169.00  169.00  169.00  169.00  X0.00    3

# %%
dfall=pd.merge(df,dfg)

# %%
dfg.tail()
# Out:
#            資料日期    代號   名稱     收盤      漲跌     開盤      最高     最低     均價  \
# 5152  108/11/07  9950  萬國通  15.70  -0.05   15.70   15.70  15.60  15.68
# 5153  108/11/07  9951   皇田  98.90  -0.70   99.60  100.00  98.70  99.11
# 5154  108/11/07  9960  邁達康  31.30  -0.30   31.30   31.90  31.25  31.51
# 5155  108/11/07  9962   有益   9.99  -0.06   10.00   10.05   9.96   9.99
# 5156  108/11/07  4415  台原藥   3.21  -0.20    3.21    3.21   3.21   3.21
#
#          成交股數        成交金額 成交筆數   最後買價   最後賣價         發行股數  次日參考價   次日漲停價  \
# 5152   24,014     376,518   14  15.60  15.75  147,716,000  15.70   17.25
# 5153  407,778  40,416,887  336  98.80  99.50   74,900,000  98.90  108.50
# 5154   81,000   2,552,600    5  31.25  31.85   33,592,500  31.30   34.40
# 5155   30,000     299,720   17   9.96   9.99   90,220,260   9.99   10.95
# 5156    3,000       9,630    1   3.18   3.68   43,577,168   3.21    3.53
#
#       次日跌停價
# 5152  14.15
# 5153  89.10
# 5154  28.20
# 5155   9.00
# 5156   2.89

# %%
dfg[dfg.代號=='3293']
# Out:
#           資料日期    代號  名稱      收盤     漲跌      開盤      最高      最低      均價  \
# 225  108/11/07  3293  鈊象  405.00  0.00   419.50  423.00  405.00  413.45
#
#           成交股數           成交金額   成交筆數   最後買價   最後賣價        發行股數  次日參考價  次日漲停價  \
# 225  2,488,766  1,028,981,698  2,291  405.0  405.5  70,382,390  405.0  445.5
#
#      次日跌停價
# 225  364.5

# %%
dff=pd.read_csv("http://www.twse.com.tw/exchangeReport/MI_INDEX?response=open_data")

# %%
dff.sort_values("漲跌百分比(%)",ascending=False)
# Out:
#            指數/報酬指數       收盤指數 漲跌(+/-)   漲跌點數 漲跌百分比(%)
# 101   電腦及週邊設備類報酬指數     189.09       +   2.77     1.49
# 33      電腦及週邊設備類指數     101.51       +   1.49     1.49
# 129      特選大蘋果報酬指數   6,300.47       +  49.07     0.78
# 34           光電類指數      39.71       +   0.29     0.74
# 102        光電類報酬指數      53.32       +   0.39     0.74
# 26         玻璃陶瓷類指數      32.48       +   0.20     0.62
# 53         臺灣IPO指數   5,438.07       +  32.29     0.60
# 94       玻璃陶瓷類報酬指數      37.15       +   0.22     0.60
# 103      通信網路類報酬指數     245.20       +   1.25     0.51
# 35         通信網路類指數     129.77       +   0.66     0.51
# 113      油電燃氣類報酬指數     184.11       +   0.89     0.49
# 68    工業菁英30反向一倍指數   8,429.74       +  41.07     0.49
# 45         油電燃氣類指數     126.46       +   0.61     0.48
# 36        電子零組件類指數     111.76       +   0.51     0.46
# 104     電子零組件類報酬指數     188.87       +   0.86     0.46
# 63      藍籌30反向一倍指數   7,747.83       +  34.27     0.44
# ...

# %%
dff.columns
# Out:
# Index(['指數/報酬指數', '收盤指數', '漲跌(+/-)', '漲跌點數', '漲跌百分比(%)'], dtype='object')

# %%
for i in range(0,137):
    if "生技"in dff['指數/報酬指數'][i]:
        print(dff['指數/報酬指數'][i])
# Out:
# 化學生技醫療類指數
# 生技醫療類指數
# 臺灣生技指數
# 化學生技醫療類報酬指數
# 生技醫療類報酬指數

# %%
dfd=pd.read_csv("http://www.twse.com.tw/exchangeReport/BWIBBU_d?response=open_data")

# %%
dfd.columns
# Out:
# Index(['證券代號', '證券名稱', '殖利率(%)', '股利年度', '本益比', '股價淨值比', '財報年/季'], dtype='object')

# %%
dfd
# Out:
#      證券代號     證券名稱   殖利率  股利年度     本益比  股價淨值比  財報年/季
# 0    1101       台泥  9.79   107    9.70   1.18  108/2
# 1    1102       亞泥  6.49   107   10.35   1.03  108/2
# 2    1103       嘉泥  5.29   107   11.81   0.55  108/2
# 3    1104       環泥  5.28   107   11.21   0.70  108/2
# 4    1108       幸福  0.00   107       -   0.74  108/2
# 5    1109       信大  4.28   107    6.75   1.01  108/2
# 6    1110       東泥  0.59   107  284.17   1.14  108/2
# 7    1201       味全  3.13   107    6.21   1.85  108/2
# 8    1203       味王  3.62   107   13.87   1.36  108/2
# 9    1210       大成  5.24   107   14.64   1.63  108/2
# 10   1213       大飲  0.00   106       -   0.62  108/2
# 11   1215       卜蜂  4.62   107   13.89   2.38  108/3
# 12   1216       統一  3.36   107   22.48   3.95  108/3
# 13   1217      愛之味  0.00   107   53.62   0.62  108/2
# 14   1218       泰山  3.73   107   21.24   1.67  108/2
# 15   1219       福壽  0.56   107       -   1.53  108/2
# 16   1220       台榮  4.60   107   24.98   0.81  108/2
# ...

# %%
dfd.columns=['證券代號', '證券名稱', '殖利率', '股利年度', '本益比', '股價淨值比', '財報年/季']

# %%
dfd[dfd.證券代號==1101]
# Out:
#    證券代號 證券名稱   殖利率  股利年度   本益比  股價淨值比  財報年/季
# 0  1101   台泥  9.79   107  9.70   1.18  108/2
