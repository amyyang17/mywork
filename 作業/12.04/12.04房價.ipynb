# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import requests
import os
import zipfile
import time

def real_estate_crawler(year, season):
    if year > 1000:
    year -= 1911

  # download real estate zip content
  res = requests.get("https://plvr.land.moi.gov.tw//DownloadSeason?season="+str(year)+"S"+str(season)+"&type=zip&fileName=lvr_landcsv.zip")

  # save content to file
  fname = str(year)+str(season)+'.zip'
    open(fname, 'wb').write(res.content)

  # make additional folder for files to extract
  folder = 'real_estate' + str(year) + str(season)
     if not os.path.isdir(folder):
    os.mkdir(folder)

  # extract files to the folder
  with zipfile.ZipFile(fname, 'r') as zip_ref:
        zip_ref.extractall(folder)

    time.sleep(10)
# Out:
#   File "<tokenize>", line 11
#     res = requests.get("https://plvr.land.moi.gov.tw//DownloadSeason?season="+str(year)+"S"+str(season)+"&type=zip&fileName=lvr_landcsv.zip")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
df
# Out:
#      district         rps01                  rps02   rps03 rps04 rps05 rps06  \
# 0         板橋區     房地(土地+建物)      新北市板橋區新生街23巷1~30號   30.44     住   NaN   NaN
# 1         板橋區  房地(土地+建物)+車位  新北市板橋區文化路一段188巷31~60號   22.60     住   NaN   NaN
# 2         板橋區            土地         文化段2191~2220地號    0.30     住   NaN   NaN
# 3         土城區     房地(土地+建物)    新北市土城區學府路一段98巷1~30號    4.19     住   NaN   NaN
# 4         板橋區  房地(土地+建物)+車位   新北市板橋區縣民大道一段271~300號   41.33     住   NaN   NaN
# ...       ...           ...                    ...     ...   ...   ...   ...
# 3631      樹林區            土地             樹新段61~90地號  104.50    其他   NaN   NaN
# 3632      樹林區            土地             樹新段61~90地號  104.50    其他   NaN   NaN
# 3633      樹林區            土地             樹新段61~90地號  214.11    其他   NaN   NaN
# 3634      樹林區  房地(土地+建物)+車位       新北市樹林區保安街二段1~30號   14.27     住   NaN   NaN
# 3635      鶯歌區  房地(土地+建物)+車位      新北市鶯歌區高職西街91~120號   21.70     住   NaN   NaN
#
#         rps07      rps08 rps09  ... rps18 rps19 rps20     rps21     rps22  \
# 0     1080630  土地1建物1車位0    四層  ...     2     有     無   9090000   80578.0
# 1     1080417  土地1建物1車位1    三層  ...     2     有     有  40470000  190149.0
# 2     1080417  土地1建物0車位0   NaN  ...     0     有     有    120000       0.0
# 3     1080627  土地1建物1車位0    九層  ...     1     有     有   3600000  123161.0
# 4     1080114  土地3建物1車位2    九層  ...     0     無     有  89680000  179352.0
# ...       ...        ...   ...  ...   ...   ...   ...       ...       ...
# 3631  1080627  土地1建物0車位0   NaN  ...     0     有     無   7409050   70900.0
# 3632  1080627  土地1建物0車位0   NaN  ...     0     有     無   7409050   70900.0
# 3633  1080627  土地1建物0車位0   NaN  ...     0     有     無  21252757   99261.0
# 3634  1080626  土地1建物1車位1    五層  ...     2     有     有   7700000   65100.0
# 3635  1080610  土地1建物1車位1    六層  ...     2     有     有   6600000   51135.0
#
#       rps23  rps24    rps25                           rps26  \
# 0       NaN   0.00        0                     含增建或未登記建物。;
# 1      坡道平面  44.59  2600000                             NaN
# 2       NaN   0.00        0                   畸零地或有合併使用之交易。
# 3       NaN   0.00        0                      含增建或未登記建物。
# 4      坡道平面  49.62  5200000                      建商與地主合建案。;
# ...     ...    ...      ...                             ...
# 3631    NaN   0.00        0                    政府機關工程用地協議價購
# 3632    NaN   0.00        0                    政府機關工程用地協議價購
# 3633    NaN   0.00        0                    政府機關工程用地協議價購
# 3634   坡道平面  17.44        0  贈熱水器.瓦斯爐.流理臺.冷氣X2.廚具.排油煙機.天然瓦斯
# 3635   坡道平面  16.42        0                             NaN
#
#                     rps27
# 0     RPRPMLMLPHOFFAF58CA
# 1     RPPNMLNLPHOFFAF28CA
# 2     RPQNMLNLPHOFFAF38CA
# 3     RPSNMLNLPHOFFAF58CA
# 4     RPTNMLNLPHOFFAF68CA
# ...                   ...
# 3631  RPQNMLRLPHOFFIF96CA
# 3632  RPRNMLRLPHOFFIF07CA
# 3633  RPSNMLRLPHOFFIF17CA
# 3634  RPUOMLTLPHOFFIF67CA
# 3635  RPVNMLKMPHOFFIF86CA
#
# [3636 rows x 28 columns]

# %%
"公寓"in df.rps11
# Out:
# False
