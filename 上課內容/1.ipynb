# %%
# %matplotlib inline
import numpy as np #數字套件
import matplotlib.pyplot as plt #繪圖套件

# %%
np.pi
# Out:
# 3.141592653589793

# %%
#繪圖
y=[1,2,3,4,5,6,7,8] #建立x,y座標
x=[1,2,3,4,5,6,7,8]

# %%
plt.plot(x,y) #折線圖

# %%
plt.scatter(x,y) #點狀圖

# %%
x1=np.linspace(-10,10,100) #將-10到10切割成100等分

# %%
y1=np.cos(x1)

# %%
plt.plot (x1,y1)

# %%
plt.xkcd() #可愛版畫線

# %%
plt.plot(x1,y1)

# %% [markdown]
# 上面自由切換code/ markdown 做筆記
# # 大標題（一個＃在前面）
# ## 小標題（數個＃在前面）

# %% [markdown]
# 快捷鍵可從help/shortcut尋找
# 1-5有教 插入連結、插入圖片、如何打出數學符號（文字前後加上$）、la-tex數學語法（可打出積分等東西）

# %% [markdown]
# # week2

# %%
name = amy
print("Hello,{}".format(name))
